# %%
import pandas as pd
sale = pd.read_csv("C:\\Users\\kemal\\Downloads\\train.csv")

# %%
sale
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
print(sale['MSSubClass'].value_counts())
# Out:
# 20     536
# 60     299
# 50     144
# 120     87
# 30      69
# 160     63
# 70      60
# 80      58
# 90      52
# 190     30
# 85      20
# 75      16
# 45      12
# 180     10
# 40       4
# Name: MSSubClass, dtype: int64

# %%
print(sale['MSZoning'].value_counts())
# Out:
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64

# %%
print(sale['LotFrontage'].value_counts())
# Out:
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
#         ...
# 112.0      1
# 138.0      1
# 149.0      1
# 38.0       1
# 111.0      1
# Name: LotFrontage, Length: 110, dtype: int64

# %%
print(sale['LotArea'].value_counts())
# Out:
# 7200     25
# 9600     24
# 6000     17
# 8400     14
# 9000     14
#          ..
# 13031     1
# 10991     1
# 8944      1
# 6897      1
# 8190      1
# Name: LotArea, Length: 1073, dtype: int64

# %%
print(sale['Street'].value_counts())
# Out:
# Pave    1454
# Grvl       6
# Name: Street, dtype: int64

# %%
print(sale['Alley'].value_counts())
# Out:
# Grvl    50
# Pave    41
# Name: Alley, dtype: int64

# %%
print(sale['LotShape'].value_counts())
# Out:
# Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: LotShape, dtype: int64

# %%
print(sale['LandContour'].value_counts())
# Out:
# Lvl    1311
# Bnk      63
# HLS      50
# Low      36
# Name: LandContour, dtype: int64

# %%
print(sale['Utilities'].value_counts())
# Out:
# AllPub    1459
# NoSeWa       1
# Name: Utilities, dtype: int64

# %%
print(sale['LotConfig'].value_counts())
# Out:
# Inside     1052
# Corner      263
# CulDSac      94
# FR2          47
# FR3           4
# Name: LotConfig, dtype: int64

# %%
print(sale['LandSlope'].value_counts())
# Out:
# Gtl    1382
# Mod      65
# Sev      13
# Name: LandSlope, dtype: int64

# %%
print(sale['Neighborhood'].value_counts())
# Out:
# NAmes      225
# CollgCr    150
# OldTown    113
# Edwards    100
# Somerst     86
# Gilbert     79
# NridgHt     77
# Sawyer      74
# NWAmes      73
# SawyerW     59
# BrkSide     58
# Crawfor     51
# Mitchel     49
# NoRidge     41
# Timber      38
# IDOTRR      37
# ClearCr     28
# SWISU       25
# StoneBr     25
# Blmngtn     17
# MeadowV     17
# BrDale      16
# Veenker     11
# NPkVill      9
# Blueste      2
# Name: Neighborhood, dtype: int64

# %%
print(sale['Condition1'].value_counts())
# Out:
# Norm      1260
# Feedr       81
# Artery      48
# RRAn        26
# PosN        19
# RRAe        11
# PosA         8
# RRNn         5
# RRNe         2
# Name: Condition1, dtype: int64

# %%
print(sale['Condition2'].value_counts())
# Out:
# Norm      1445
# Feedr        6
# PosN         2
# RRNn         2
# Artery       2
# RRAe         1
# RRAn         1
# PosA         1
# Name: Condition2, dtype: int64

# %%
print(sale['BldgType'].value_counts())
# Out:
# 1Fam      1220
# TwnhsE     114
# Duplex      52
# Twnhs       43
# 2fmCon      31
# Name: BldgType, dtype: int64

# %%
print(sale['HouseStyle'].value_counts())
# Out:
# 1Story    726
# 2Story    445
# 1.5Fin    154
# SLvl       65
# SFoyer     37
# 1.5Unf     14
# 2.5Unf     11
# 2.5Fin      8
# Name: HouseStyle, dtype: int64

# %%
print(sale['OverallQual'].value_counts())
# Out:
# 5     397
# 6     374
# 7     319
# 8     168
# 4     116
# 9      43
# 3      20
# 10     18
# 2       3
# 1       2
# Name: OverallQual, dtype: int64

# %%
print(sale['OverallCond'].value_counts())
# Out:
# 5    821
# 6    252
# 7    205
# 8     72
# 4     57
# 3     25
# 9     22
# 2      5
# 1      1
# Name: OverallCond, dtype: int64

# %%
print(sale['YearBuilt'].value_counts())
# Out:
# 2006    67
# 2005    64
# 2004    54
# 2007    49
# 2003    45
#         ..
# 1904     1
# 1898     1
# 1893     1
# 1882     1
# 2010     1
# Name: YearBuilt, Length: 112, dtype: int64

# %%
print(sale['YearRemodAdd'].value_counts())
# Out:
# 1950    178
# 2006     97
# 2007     76
# 2005     73
# 2004     62
#        ...
# 2010      6
# 1983      5
# 1986      5
# 1952      5
# 1951      4
# Name: YearRemodAdd, Length: 61, dtype: int64

# %%
print(sale['RoofStyle'].value_counts())
# Out:
# Gable      1141
# Hip         286
# Flat         13
# Gambrel      11
# Mansard       7
# Shed          2
# Name: RoofStyle, dtype: int64

# %%
print(sale['RoofMatl'].value_counts())
# Out:
# CompShg    1434
# Tar&Grv      11
# WdShngl       6
# WdShake       5
# Roll          1
# Membran       1
# Metal         1
# ClyTile       1
# Name: RoofMatl, dtype: int64

# %%
print(sale['Exterior1st'].value_counts())
# Out:
# VinylSd    515
# HdBoard    222
# MetalSd    220
# Wd Sdng    206
# Plywood    108
# CemntBd     61
# BrkFace     50
# WdShing     26
# Stucco      25
# AsbShng     20
# BrkComm      2
# Stone        2
# CBlock       1
# ImStucc      1
# AsphShn      1
# Name: Exterior1st, dtype: int64

# %%
print(sale['Exterior2nd'].value_counts())
# Out:
# VinylSd    504
# MetalSd    214
# HdBoard    207
# Wd Sdng    197
# Plywood    142
# CmentBd     60
# Wd Shng     38
# Stucco      26
# BrkFace     25
# AsbShng     20
# ImStucc     10
# Brk Cmn      7
# Stone        5
# AsphShn      3
# CBlock       1
# Other        1
# Name: Exterior2nd, dtype: int64

# %%
print(sale['MasVnrType'].value_counts())
# Out:
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64

# %%
print(sale['MasVnrArea'].value_counts())
# Out:
# 0.0      861
# 108.0      8
# 72.0       8
# 180.0      8
# 16.0       7
#         ...
# 31.0       1
# 366.0      1
# 528.0      1
# 894.0      1
# 415.0      1
# Name: MasVnrArea, Length: 327, dtype: int64

# %%
print(sale['ExterQual'].value_counts())
# Out:
# TA    906
# Gd    488
# Ex     52
# Fa     14
# Name: ExterQual, dtype: int64

# %%
print(sale['ExterCond'].value_counts())
# Out:
# TA    1282
# Gd     146
# Fa      28
# Ex       3
# Po       1
# Name: ExterCond, dtype: int64

# %%
print(sale['Foundation'].value_counts())
# Out:
# PConc     647
# CBlock    634
# BrkTil    146
# Slab       24
# Stone       6
# Wood        3
# Name: Foundation, dtype: int64

# %%
print(sale['BsmtQual'].value_counts())
# Out:
# TA    649
# Gd    618
# Ex    121
# Fa     35
# Name: BsmtQual, dtype: int64

# %%
print(sale['BsmtCond'].value_counts())
# Out:
# TA    1311
# Gd      65
# Fa      45
# Po       2
# Name: BsmtCond, dtype: int64

# %%
print(sale['BsmtExposure'].value_counts())
# Out:
# No    953
# Av    221
# Gd    134
# Mn    114
# Name: BsmtExposure, dtype: int64

# %%
print(sale['BsmtFinType1'].value_counts())
# Out:
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# Name: BsmtFinType1, dtype: int64

# %%
print(sale['BsmtFinSF1'].value_counts())
# Out:
# 0       467
# 24       12
# 16        9
# 20        5
# 686       5
#        ...
# 535       1
# 534       1
# 532       1
# 522       1
# 2096      1
# Name: BsmtFinSF1, Length: 637, dtype: int64

# %%
print(sale['BsmtFinType2'].value_counts())
# Out:
# Unf    1256
# Rec      54
# LwQ      46
# BLQ      33
# ALQ      19
# GLQ      14
# Name: BsmtFinType2, dtype: int64

# %%
print(sale['BsmtFinSF2'].value_counts())
# Out:
# 0       1293
# 180        5
# 374        3
# 117        2
# 391        2
#         ...
# 215        1
# 211        1
# 210        1
# 208        1
# 1474       1
# Name: BsmtFinSF2, Length: 144, dtype: int64

# %%
print(sale['BsmtUnfSF'].value_counts())
# Out:
# 0       118
# 728       9
# 384       8
# 572       7
# 600       7
#        ...
# 549       1
# 548       1
# 545       1
# 543       1
# 2046      1
# Name: BsmtUnfSF, Length: 780, dtype: int64

# %%
print(sale['TotalBsmtSF'].value_counts())
# Out:
# 0       37
# 864     35
# 672     17
# 912     15
# 1040    14
#         ..
# 1210     1
# 727      1
# 1205     1
# 1203     1
# 2046     1
# Name: TotalBsmtSF, Length: 721, dtype: int64

# %%
print(sale['Heating'].value_counts())
# Out:
# GasA     1428
# GasW       18
# Grav        7
# Wall        4
# OthW        2
# Floor       1
# Name: Heating, dtype: int64

# %%
print(sale['HeatingQC'].value_counts())
# Out:
# Ex    741
# TA    428
# Gd    241
# Fa     49
# Po      1
# Name: HeatingQC, dtype: int64

# %%
print(sale['CentralAir'].value_counts())
# Out:
# Y    1365
# N      95
# Name: CentralAir, dtype: int64

# %%
print(sale['Electrical'].value_counts())
# Out:
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: Electrical, dtype: int64

# %%
print(sale['1stFlrSF'].value_counts())
# Out:
# 864     25
# 1040    16
# 912     14
# 848     12
# 894     12
#         ..
# 1061     1
# 1058     1
# 1051     1
# 1047     1
# 2046     1
# Name: 1stFlrSF, Length: 753, dtype: int64

# %%
print(sale['2ndFlrSF'].value_counts())
# Out:
# 0       829
# 728      10
# 504       9
# 672       8
# 546       8
#        ...
# 812       1
# 811       1
# 473       1
# 475       1
# 1872      1
# Name: 2ndFlrSF, Length: 417, dtype: int64

# %%
print(sale['LowQualFinSF'].value_counts())
# Out:
# 0      1434
# 80        3
# 360       2
# 392       1
# 528       1
# 515       1
# 514       1
# 513       1
# 481       1
# 479       1
# 473       1
# 420       1
# 397       1
# 390       1
# 53        1
# 384       1
# 371       1
# 234       1
# 232       1
# 205       1
# 156       1
# 144       1
# 120       1
# 572       1
# Name: LowQualFinSF, dtype: int64

# %%
print(sale['GrLivArea'].value_counts())
# Out:
# 864     22
# 1040    14
# 894     11
# 848     10
# 1456    10
#         ..
# 2792     1
# 2794     1
# 1349     1
# 1347     1
# 2054     1
# Name: GrLivArea, Length: 861, dtype: int64

# %%
print(sale['BsmtFullBath'].value_counts())
# Out:
# 0    856
# 1    588
# 2     15
# 3      1
# Name: BsmtFullBath, dtype: int64

# %%
print(sale['BsmtHalfBath'].value_counts())
# Out:
# 0    1378
# 1      80
# 2       2
# Name: BsmtHalfBath, dtype: int64

# %%
print(sale['FullBath'].value_counts())
# Out:
# 2    768
# 1    650
# 3     33
# 0      9
# Name: FullBath, dtype: int64

# %%
print(sale['HalfBath'].value_counts())
# Out:
# 0    913
# 1    535
# 2     12
# Name: HalfBath, dtype: int64

# %%
print(sale['BedroomAbvGr'].value_counts())
# Out:
# 3    804
# 2    358
# 4    213
# 1     50
# 5     21
# 6      7
# 0      6
# 8      1
# Name: BedroomAbvGr, dtype: int64

# %%
print(sale['KitchenAbvGr'].value_counts())
# Out:
# 1    1392
# 2      65
# 3       2
# 0       1
# Name: KitchenAbvGr, dtype: int64

# %%
print(sale['KitchenQual'].value_counts())
# Out:
# TA    735
# Gd    586
# Ex    100
# Fa     39
# Name: KitchenQual, dtype: int64

# %%
print(sale['TotRmsAbvGrd'].value_counts())
# Out:
# 6     402
# 7     329
# 5     275
# 8     187
# 4      97
# 9      75
# 10     47
# 11     18
# 3      17
# 12     11
# 2       1
# 14      1
# Name: TotRmsAbvGrd, dtype: int64

# %%
print(sale['Functional'].value_counts())
# Out:
# Typ     1360
# Min2      34
# Min1      31
# Mod       15
# Maj1      14
# Maj2       5
# Sev        1
# Name: Functional, dtype: int64

# %%
print(sale['Fireplaces'].value_counts())
# Out:
# 0    690
# 1    650
# 2    115
# 3      5
# Name: Fireplaces, dtype: int64

# %%
print(sale['FireplaceQu'].value_counts())
# Out:
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: FireplaceQu, dtype: int64

# %%
print(sale['GarageType'].value_counts())
# Out:
# Attchd     870
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64

# %%
print(sale['GarageYrBlt'].value_counts())
# Out:
# 2005.0    65
# 2006.0    59
# 2004.0    53
# 2003.0    50
# 2007.0    49
#           ..
# 1906.0     1
# 1908.0     1
# 1933.0     1
# 1900.0     1
# 1927.0     1
# Name: GarageYrBlt, Length: 97, dtype: int64

# %%
print(sale['GarageFinish'].value_counts())
# Out:
# Unf    605
# RFn    422
# Fin    352
# Name: GarageFinish, dtype: int64

# %%
print(sale['GarageCars'].value_counts())
# Out:
# 2    824
# 1    369
# 3    181
# 0     81
# 4      5
# Name: GarageCars, dtype: int64

# %%
print(sale['GarageArea'].value_counts())
# Out:
# 0       81
# 440     49
# 576     47
# 240     38
# 484     34
#         ..
# 671      1
# 342      1
# 673      1
# 675      1
# 1418     1
# Name: GarageArea, Length: 441, dtype: int64

# %%
print(sale['GarageQual'].value_counts())
# Out:
# TA    1311
# Fa      48
# Gd      14
# Po       3
# Ex       3
# Name: GarageQual, dtype: int64

# %%
print(sale['GarageCond'].value_counts())
# Out:
# TA    1326
# Fa      35
# Gd       9
# Po       7
# Ex       2
# Name: GarageCond, dtype: int64

# %%
print(sale['PavedDrive'].value_counts())
# Out:
# Y    1340
# N      90
# P      30
# Name: PavedDrive, dtype: int64

# %%
print(sale['WoodDeckSF'].value_counts())
# Out:
# 0      761
# 192     38
# 100     36
# 144     33
# 120     31
#       ...
# 103      1
# 269      1
# 98       1
# 97       1
# 857      1
# Name: WoodDeckSF, Length: 274, dtype: int64

# %%
print(sale['OpenPorchSF'].value_counts())
# Out:
# 0      656
# 36      29
# 48      22
# 20      21
# 45      19
#       ...
# 141      1
# 137      1
# 135      1
# 134      1
# 547      1
# Name: OpenPorchSF, Length: 202, dtype: int64

# %%
print(sale['EnclosedPorch'].value_counts())
# Out:
# 0      1252
# 112      15
# 96        6
# 120       5
# 192       5
#        ...
# 170       1
# 169       1
# 67        1
# 68        1
# 552       1
# Name: EnclosedPorch, Length: 120, dtype: int64

# %%
print(sale['3SsnPorch'].value_counts())
# Out:
# 0      1436
# 168       3
# 216       2
# 144       2
# 180       2
# 407       1
# 320       1
# 304       1
# 290       1
# 245       1
# 238       1
# 182       1
# 196       1
# 23        1
# 162       1
# 153       1
# 140       1
# 130       1
# 96        1
# 508       1
# Name: 3SsnPorch, dtype: int64

# %%
print(sale['ScreenPorch'].value_counts())
# Out:
# 0      1344
# 192       6
# 120       5
# 224       5
# 180       4
#        ...
# 175       1
# 178       1
# 40        1
# 185       1
# 480       1
# Name: ScreenPorch, Length: 76, dtype: int64

# %%
print(sale['PoolArea'].value_counts())
# Out:
# 0      1453
# 480       1
# 512       1
# 519       1
# 555       1
# 576       1
# 648       1
# 738       1
# Name: PoolArea, dtype: int64

# %%
print(sale['PoolQC'].value_counts())
# Out:
# Gd    3
# Ex    2
# Fa    2
# Name: PoolQC, dtype: int64

# %%
print(sale['Fence'].value_counts())
# Out:
# MnPrv    157
# GdPrv     59
# GdWo      54
# MnWw      11
# Name: Fence, dtype: int64

# %%
print(sale['MSZoning'].value_counts())
# Out:
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64

# %%
print(sale['MiscFeature'].value_counts())
# Out:
# Shed    49
# Othr     2
# Gar2     2
# TenC     1
# Name: MiscFeature, dtype: int64

# %%
print(sale['MiscVal'].value_counts())
# Out:
# 0        1408
# 400        11
# 500         8
# 700         5
# 450         4
# 600         4
# 2000        4
# 480         2
# 1200        2
# 2500        1
# 350         1
# 560         1
# 54          1
# 620         1
# 8300        1
# 800         1
# 1150        1
# 15500       1
# 1300        1
# 1400        1
# 3500        1
# Name: MiscVal, dtype: int64

# %%
print(sale['MoSold'].value_counts())
# Out:
# 6     253
# 7     234
# 5     204
# 4     141
# 8     122
# 3     106
# 10     89
# 11     79
# 9      63
# 12     59
# 1      58
# 2      52
# Name: MoSold, dtype: int64

# %%
print(sale['YrSold'].value_counts())
# Out:
# 2009    338
# 2007    329
# 2006    314
# 2008    304
# 2010    175
# Name: YrSold, dtype: int64

# %%
print(sale['SaleType'].value_counts())
# Out:
# WD       1267
# New       122
# COD        43
# ConLD       9
# ConLI       5
# ConLw       5
# CWD         4
# Oth         3
# Con         2
# Name: SaleType, dtype: int64

# %%
print(sale['SaleCondition'].value_counts())
# Out:
# Normal     1198
# Partial     125
# Abnorml     101
# Family       20
# Alloca       12
# AdjLand       4
# Name: SaleCondition, dtype: int64

# %%
print(sale['SalePrice'].value_counts())
# Out:
# 140000    20
# 135000    17
# 155000    14
# 145000    14
# 190000    13
#           ..
# 337000     1
# 412500     1
# 306000     1
# 195400     1
# 206000     1
# Name: SalePrice, Length: 663, dtype: int64

# %%
sale.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
sale.duplicated().sum()
# Out:
# 0

# %%
# create a boolean mask of the DataFrame indicating which values are missing
missing_values_mask = sale.isnull()

# count the number of missing values in each column
missing_values_count = missing_values_mask.sum()

# create a DataFrame showing the columns with missing values and the number of missing values in each column
missing_values_sale = pd.DataFrame({'column_name': sale.columns, 'missing_values': missing_values_count})

# filter the DataFrame to show only columns with missing values
missing_values_sale = missing_values_sale[missing_values_sale['missing_values'] > 0]

print(missing_values_sale)
# Out:
#                column_name  missing_values
# LotFrontage    LotFrontage             259
# Alley                Alley            1369
# MasVnrType      MasVnrType               8
# MasVnrArea      MasVnrArea               8
# BsmtQual          BsmtQual              37
# BsmtCond          BsmtCond              37
# BsmtExposure  BsmtExposure              38
# BsmtFinType1  BsmtFinType1              37
# BsmtFinType2  BsmtFinType2              38
# Electrical      Electrical               1
# FireplaceQu    FireplaceQu             690
# GarageType      GarageType              81
# GarageYrBlt    GarageYrBlt              81
# GarageFinish  GarageFinish              81
# GarageQual      GarageQual              81
# GarageCond      GarageCond              81
# PoolQC              PoolQC            1453
# Fence                Fence            1179
# MiscFeature    MiscFeature            1406

# %%
# calculate the proportion of missing values in each column
missing_values_prop = sale.isnull().mean()

# filter to only show columns with missing values
missing_cols = missing_values_prop[missing_values_prop > 0]

# print the columns with missing values and the proportion of missing values
print(missing_cols)
# Out:
# LotFrontage     0.177397
# Alley           0.937671
# MasVnrType      0.005479
# MasVnrArea      0.005479
# BsmtQual        0.025342
# BsmtCond        0.025342
# BsmtExposure    0.026027
# BsmtFinType1    0.025342
# BsmtFinType2    0.026027
# Electrical      0.000685
# FireplaceQu     0.472603
# GarageType      0.055479
# GarageYrBlt     0.055479
# GarageFinish    0.055479
# GarageQual      0.055479
# GarageCond      0.055479
# PoolQC          0.995205
# Fence           0.807534
# MiscFeature     0.963014
# dtype: float64

# %%
# get the names of columns to drop
cols_to_drop = missing_values_prop[missing_values_prop > 0.1].index

# drop the columns from the DataFrame
sale.drop(cols_to_drop, axis=1, inplace=True)

# print the updated DataFrame
print(sale)
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 0        1          60       RL     8450   Pave      Reg         Lvl
# 1        2          20       RL     9600   Pave      Reg         Lvl
# 2        3          60       RL    11250   Pave      IR1         Lvl
# 3        4          70       RL     9550   Pave      IR1         Lvl
# 4        5          60       RL    14260   Pave      IR1         Lvl
# ...    ...         ...      ...      ...    ...      ...         ...
# 1455  1456          60       RL     7917   Pave      Reg         Lvl
# 1456  1457          20       RL    13175   Pave      Reg         Lvl
# 1457  1458          70       RL     9042   Pave      Reg         Lvl
# 1458  1459          20       RL     9717   Pave      Reg         Lvl
# 1459  1460          20       RL     9937   Pave      Reg         Lvl
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %%
sale.drop('Id', axis=1, inplace=True)

# %%
# create a dictionary to map categorical data to numerical values
mapping = {
    'A': 0,
    'C': 1,
    'FV': 2,
    'I': 3,
    'RH': 4,
    'RL': 5,
    'RP': 6,
    'RM': 7
}

# replace the categorical values with numerical values
sale['MSZoning'] = sale['MSZoning'].replace(mapping)

# print the updated DataFrame
print(sale)
# Out:
#       MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0             60        5     8450   Pave      Reg         Lvl    AllPub
# 1             20        5     9600   Pave      Reg         Lvl    AllPub
# 2             60        5    11250   Pave      IR1         Lvl    AllPub
# 3             70        5     9550   Pave      IR1         Lvl    AllPub
# 4             60        5    14260   Pave      IR1         Lvl    AllPub
# ...          ...      ...      ...    ...      ...         ...       ...
# 1455          60        5     7917   Pave      Reg         Lvl    AllPub
# 1456          20        5    13175   Pave      Reg         Lvl    AllPub
# 1457          70        5     9042   Pave      Reg         Lvl    AllPub
# 1458          20        5     9717   Pave      Reg         Lvl    AllPub
# 1459          20        5     9937   Pave      Reg         Lvl    AllPub
#
#      LotConfig LandSlope Neighborhood  ... EnclosedPorch 3SsnPorch  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# create a dictionary to map each categorical variable to its corresponding LabelEncoder object
le_dict = {}

def encode_categorical(sale, var):
    le = LabelEncoder()
    sale[var] = sale[var].astype(str)  # convert the column to string type
    sale[var] = le.fit_transform(sale[var])
    le_dict[var] = le
    return sale

# example usage
sale = encode_categorical(sale, 'Street')
print(le_dict)  # should print {'Street': LabelEncoder()}
# Out:
# {'Street': LabelEncoder()}

# %%
encode_categorical(sale, 'MSZoning')
encode_categorical(sale, 'Street')
encode_categorical(sale, 'LotShape')
encode_categorical(sale, 'LandContour')
encode_categorical(sale, 'Utilities')
encode_categorical(sale, 'LotConfig')
encode_categorical(sale, 'LandSlope')
encode_categorical(sale, 'Neighborhood')
encode_categorical(sale, 'Condition1')
encode_categorical(sale, 'Condition2')
encode_categorical(sale, 'BldgType')
encode_categorical(sale, 'HouseStyle')
encode_categorical(sale, 'YearBuilt')
encode_categorical(sale, 'YearRemodAdd')
encode_categorical(sale, 'RoofStyle')
encode_categorical(sale, 'RoofMatl')
encode_categorical(sale, 'Exterior1st')
encode_categorical(sale, 'Exterior2nd')
encode_categorical(sale, 'MasVnrType')
encode_categorical(sale, 'ExterQual')
encode_categorical(sale, 'ExterCond')
encode_categorical(sale, 'Foundation')
encode_categorical(sale, 'BsmtQual')
encode_categorical(sale, 'BsmtCond')
encode_categorical(sale, 'BsmtExposure')
encode_categorical(sale, 'BsmtFinType1')
encode_categorical(sale, 'BsmtFinType2')
encode_categorical(sale, 'Heating')
encode_categorical(sale, 'HeatingQC')
encode_categorical(sale, 'CentralAir')
encode_categorical(sale, 'Electrical')
encode_categorical(sale, 'KitchenQual')
encode_categorical(sale, 'Functional')
encode_categorical(sale, 'GarageType')
encode_categorical(sale, 'GarageYrBlt')
encode_categorical(sale, 'GarageFinish')
encode_categorical(sale, 'GarageQual')
encode_categorical(sale, 'GarageCond')
encode_categorical(sale, 'PavedDrive')
encode_categorical(sale, 'YrSold')
encode_categorical(sale, 'SaleType')
encode_categorical(sale, 'SaleCondition')
sale
# Out:
#       MSSubClass  MSZoning  LotArea  Street  LotShape  LandContour  Utilities  \
# 0             60         2     8450       1         3            3          0
# 1             20         2     9600       1         3            3          0
# 2             60         2    11250       1         0            3          0
# 3             70         2     9550       1         0            3          0
# 4             60         2    14260       1         0            3          0
# ...          ...       ...      ...     ...       ...          ...        ...
# 1455          60         2     7917       1         3            3          0
# 1456          20         2    13175       1         3            3          0
# 1457          70         2     9042       1         3            3          0
# 1458          20         2     9717       1         3            3          0
# 1459          20         2     9937       1         3            3          0
#
# ...

# %%
sale.describe()
# Out:
#         MSSubClass     MSZoning        LotArea       Street     LotShape  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260     2.063014   10516.828082     0.995890     1.942466
# std      42.300571     0.601690    9981.264932     0.063996     1.409156
# min      20.000000     0.000000    1300.000000     0.000000     0.000000
# 25%      20.000000     2.000000    7553.500000     1.000000     0.000000
# 50%      50.000000     2.000000    9478.500000     1.000000     3.000000
# 75%      70.000000     2.000000   11601.500000     1.000000     3.000000
# max     190.000000     4.000000  215245.000000     1.000000     3.000000
#
#        LandContour    Utilities    LotConfig    LandSlope  Neighborhood  ...  \
# count  1460.000000  1460.000000  1460.000000  1460.000000   1460.000000  ...
# mean      2.777397     0.000685     3.019178     0.062329     12.251370  ...
# std       0.707666     0.026171     1.622634     0.276232      6.013735  ...
# ...

# %%
import matplotlib.pyplot as plt

pd.plotting.scatter_matrix(sale, figsize=(13,15)) # plot the data
plt.show()

# %%
import seaborn as sns

corr = sale.corr()
plt.subplots(figsize=(10,10))
sns.heatmap(corr, vmin=-1, center=0, vmax=1, annot=True)
plt.show()

# %%
import pandas as pd

nan_mask = sale.isna()  # create a Boolean mask indicating the locations of NaN values
if nan_mask.any().any():
    print("Data contains NaN values.")
    sale.fillna(sale.mean(), inplace=True)  # impute NaN values with the mean value
# Out:
# Data contains NaN values.

# %%
sale
# Out:
#       MSSubClass  MSZoning  LotArea  Street  LotShape  LandContour  Utilities  \
# 0             60         2     8450       1         3            3          0
# 1             20         2     9600       1         3            3          0
# 2             60         2    11250       1         0            3          0
# 3             70         2     9550       1         0            3          0
# 4             60         2    14260       1         0            3          0
# ...          ...       ...      ...     ...       ...          ...        ...
# 1455          60         2     7917       1         3            3          0
# 1456          20         2    13175       1         3            3          0
# 1457          70         2     9042       1         3            3          0
# 1458          20         2     9717       1         3            3          0
# 1459          20         2     9937       1         3            3          0
#
# ...

# %%
import pandas as pd

nan_mask = sale.isna()  # create a Boolean mask indicating the locations of NaN values
if nan_mask.any().any():
    print("Data contains NaN values.")
    sale.fillna(sale.mean(), inplace=True)  # impute NaN values with the mean value

# %%
X = sale.drop('SalePrice',axis=1).copy()
Y = sale.iloc[:,[-1]]

# %%
X
# Out:
#       MSSubClass  MSZoning  LotArea  Street  LotShape  LandContour  Utilities  \
# 0             60         2     8450       1         3            3          0
# 1             20         2     9600       1         3            3          0
# 2             60         2    11250       1         0            3          0
# 3             70         2     9550       1         0            3          0
# 4             60         2    14260       1         0            3          0
# ...          ...       ...      ...     ...       ...          ...        ...
# 1455          60         2     7917       1         3            3          0
# 1456          20         2    13175       1         3            3          0
# 1457          70         2     9042       1         3            3          0
# 1458          20         2     9717       1         3            3          0
# 1459          20         2     9937       1         3            3          0
#
# ...

# %%
Y
# Out:
#       SalePrice
# 0        208500
# 1        181500
# 2        223500
# 3        140000
# 4        250000
# ...         ...
# 1455     175000
# 1456     210000
# 1457     266500
# 1458     142125
# 1459     147500
#
# [1460 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
sale.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotArea', 'Street', 'LotShape',
#        'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood',
#        'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl',
#        'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual',
#        'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
#        'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical',
#        '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath',
#        'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr',
#        'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
# melihat apakah ada string di DataFrame
categorical_cols = sale.select_dtypes(include=['object']).columns
categorical_cols
# Out:
# Index([], dtype='object')

# %%
X_train
# Out:
#       MSSubClass  MSZoning  LotArea  Street  LotShape  LandContour  Utilities  \
# 254           20         2     8400       1         3            3          0
# 1066          60         2     7837       1         0            3          0
# 638           30         2     8777       1         3            3          0
# 799           50         2     7200       1         3            3          0
# 380           50         2     5000       1         3            3          0
# ...          ...       ...      ...     ...       ...          ...        ...
# 1095          20         2     9317       1         0            3          0
# 1130          50         2     7804       1         3            3          0
# 1294          20         2     8172       1         3            3          0
# 860           50         2     7642       1         3            3          0
# 1126         120         2     3684       1         3            3          0
#
# ...

# %%
from sklearn.feature_selection import SelectKBest, f_classif

# X is the input features and y is the target variable
selector = SelectKBest(score_func=f_classif, k=5)
X_train = selector.fit_transform(X, Y)

# print the scores of each feature
scores = pd.DataFrame({'Feature': X.columns, 'Score': selector.scores_})
scores.sort_values(by='Score', ascending=False, inplace=True)
print(scores)
# Out:
#           Feature     Score
# 14    OverallQual  5.729183
# 24      ExterQual  3.774880
# 68        MiscVal  3.756250
# 43      GrLivArea  3.435110
# 2         LotArea  3.285852
# ..            ...       ...
# 52     Functional  0.803986
# 64  EnclosedPorch  0.797050
# 60     GarageCond  0.779559
# 10     Condition1  0.777743
# 6       Utilities  0.239796
#
# [73 rows x 2 columns]
# C:\Users\kemal\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
scores
# Out:
#           Feature     Score
# 14    OverallQual  5.729183
# 24      ExterQual  3.774880
# 68        MiscVal  3.756250
# 43      GrLivArea  3.435110
# 2         LotArea  3.285852
# ..            ...       ...
# 52     Functional  0.803986
# 64  EnclosedPorch  0.797050
# 60     GarageCond  0.779559
# 10     Condition1  0.777743
# 6       Utilities  0.239796
#
# [73 rows x 2 columns]

# %%
data1['SalePrice']=sale['SalePrice']
# Out:
# <ipython-input-544-5b6501e99de2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['SalePrice']=sale['SalePrice']

# %%
#define IQR to remove data outlier
Q1 = data1.quantile(q=.25)
Q3 = data1.quantile(q=.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# OverallQual        2.00
# ExterQual          1.00
# BsmtQual           1.00
# TotalBsmtSF      502.50
# 1stFlrSF         509.25
# GrLivArea        647.25
# FullBath           1.00
# KitchenQual        1.00
# GarageCars         1.00
# GarageArea       241.50
# SalePrice      84025.00
# dtype: float64

# %%
#remove data outlier
data1 = data1[~((data1<(Q1-1.5*IQR)) | (data1>(Q3+1.5*IQR)))]
data1
# Out:
#       OverallQual  ExterQual  BsmtQual  TotalBsmtSF  1stFlrSF  GrLivArea  \
# 0             7.0        2.0       2.0        856.0     856.0     1710.0
# 1             6.0        3.0       2.0       1262.0    1262.0     1262.0
# 2             7.0        2.0       2.0        920.0     920.0     1786.0
# 3             7.0        3.0       3.0        756.0     961.0     1717.0
# 4             8.0        2.0       2.0       1145.0    1145.0     2198.0
# ...           ...        ...       ...          ...       ...        ...
# 1455          6.0        3.0       2.0        953.0     953.0     1647.0
# 1456          6.0        3.0       2.0       1542.0    2073.0     2073.0
# 1457          7.0        NaN       3.0       1152.0    1188.0     2340.0
# 1458          5.0        3.0       3.0       1078.0    1078.0     1078.0
# 1459          5.0        2.0       3.0       1256.0    1256.0     1256.0
#
#       FullBath  KitchenQual  GarageCars  GarageArea  SalePrice
# ...

# %%
data1.isna().sum()
# Out:
# OverallQual      2
# ExterQual       52
# BsmtQual       121
# TotalBsmtSF     61
# 1stFlrSF        20
# GrLivArea       31
# FullBath         0
# KitchenQual    100
# GarageCars       5
# GarageArea      21
# SalePrice       61
# dtype: int64

# %%
from sklearn.impute import KNNImputer

# %%
#impute data outlier that removed before with KNNImputer
imputer = KNNImputer()
imputasi_knn=imputer.fit_transform(data1)
data1=pd.DataFrame(data=imputasi_knn, columns=data1.columns)
data1.head()
# Out:
#    OverallQual  ExterQual  BsmtQual  TotalBsmtSF  1stFlrSF  GrLivArea  \
# 0          7.0        2.0       2.0        856.0     856.0     1710.0
# 1          6.0        3.0       2.0       1262.0    1262.0     1262.0
# 2          7.0        2.0       2.0        920.0     920.0     1786.0
# 3          7.0        3.0       3.0        756.0     961.0     1717.0
# 4          8.0        2.0       2.0       1145.0    1145.0     2198.0
#
#    FullBath  KitchenQual  GarageCars  GarageArea  SalePrice
# 0       2.0          2.0         2.0       548.0   208500.0
# 1       2.0          3.0         2.0       460.0   181500.0
# 2       2.0          2.0         2.0       608.0   223500.0
# 3       1.0          2.0         3.0       642.0   140000.0
# 4       2.0          2.0         3.0       836.0   250000.0

# %%
data1.isna().sum()
# Out:
# OverallQual    0
# ExterQual      0
# BsmtQual       0
# TotalBsmtSF    0
# 1stFlrSF       0
# GrLivArea      0
# FullBath       0
# KitchenQual    0
# GarageCars     0
# GarageArea     0
# SalePrice      0
# dtype: int64

# %%
#check duplicate
data1.duplicated().sum()
# Out:
# 0

# %%
#statistic descriptive from data
data1.describe()
# Out:
#        OverallQual    ExterQual     BsmtQual  TotalBsmtSF     1stFlrSF  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean      6.108082     2.614658     2.485068  1069.993151  1151.906027
# std       1.371047     0.503780     0.583080   348.789556   351.550229
# min       2.000000     1.000000     1.000000   105.000000   334.000000
# 25%       5.000000     2.000000     2.000000   815.750000   882.000000
# 50%       6.000000     3.000000     2.200000  1009.000000  1087.000000
# 75%       7.000000     3.000000     3.000000  1306.000000  1391.000000
# max      10.000000     3.000000     4.000000  2046.000000  2136.000000
#
#          GrLivArea     FullBath  KitchenQual   GarageCars   GarageArea  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean   1492.424521     1.565068     2.484932     1.762603   467.628630
# std     458.080586     0.550916     0.546626     0.738038   201.957645
# ...

# %%
sns.boxplot(data=data1)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
X1=data1.drop('SalePrice',axis=1)
y1=data1['SalePrice']

# %%
#pemilihan komposisi splitting data
lr = LinearRegression()
L=[]
for i in range(1,6):
    X_train, X_test, y_train, y_test = train_test_split(X1.values, y1.values, test_size=0.1*i, random_state=42)
    lr.fit(X_train,y_train)
    y_pred = lr.predict(X_test)
    L.append(r2_score(y_pred,y_test))
print(L)
# Out:
# [0.7968045355721786, 0.7627515385955003, 0.7671164860130566, 0.7610059513059848, 0.7400322002958285]

# %%
X_train, X_test, y_train, y_test = train_test_split(X1.values, y1.values, test_size=0.1, random_state=42)
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)
print(r2_score(y_pred,y_test))
# Out:
# 0.7968045355721786

# %%
import joblib
joblib.dump(lr,'model_regresi_linier.pkl')
# Out:
# ['model_regresi_linier.pkl']

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
col = ['OverallQual', 'ExterQual', 'BsmtQual', 'TotalBsmtQual', '1stFlrSF', 'GrLivArea', 'FullBath', 'KitchenQual', 'GarageCars', 'GarageArea']
X_train.loc[:,col] = sc.fit_transform(X_train.loc[:,col])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-564-f09cd07b3631> in <module>
#       2 sc = StandardScaler()
#       3 col = ['OverallQual', 'ExterQual', 'BsmtQual', 'TotalBsmtQual', '1stFlrSF', 'GrLivArea', 'FullBath', 'KitchenQual', 'GarageCars', 'GarageArea']
# ----> 4 X_train.loc[:,col] = sc.fit_transform(X_train.loc[:,col])
#
# AttributeError: 'numpy.ndarray' object has no attribute 'loc'

# %%
#Select best feature with SelectKBest
from sklearn.feature_selection import SelectKBest, f_regression

selector = SelectKBest(score_func=f_regression, k=10)
X_new = selector.fit_transform(X, Y)
selected_num_features = X.columns[selector.get_support()]
data1=X[selected_num_features]
data1
# Out:
# C:\Users\kemal\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
#       OverallQual  ExterQual  BsmtQual  TotalBsmtSF  1stFlrSF  GrLivArea  \
# 0               7          2         2          856       856       1710
# 1               6          3         2         1262      1262       1262
# 2               7          2         2          920       920       1786
# 3               7          3         3          756       961       1717
# 4               8          2         2         1145      1145       2198
# ...           ...        ...       ...          ...       ...        ...
# 1455            6          3         2          953       953       1647
# 1456            6          3         2         1542      2073       2073
# ...

# %%
X_test.loc[:,col] = sc.transform(X_test.loc[:,col])
X_test
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-561-c33fe54987ae> in <module>
# ----> 1 X_test.loc[:,col] = sc.transform(X_test.loc[:,col])
#       2 X_test
#
# AttributeError: 'numpy.ndarray' object has no attribute 'loc'

# %%
import numpy as np

# Assuming 'sale' is your DataFrame
if not np.isfinite(sale.to_numpy()).all():
    print("Data contains values too large for dtype('float64').")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
# %matplotlib inline

log_regr = LogisticRegression()
svc = SVC()
dt = DecisionTreeClassifier()
rf = RandomForestClassifier()

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
# melakukan cross validation pada masing-masing metode
lr_score = cross_val_score(log_regr, X_train, Y_train, cv=kfold, scoring='f1').mean()
svc_score = cross_val_score(svc, X_train, Y_train, cv=kfold, scoring='f1').mean()
dt_score = cross_val_score(dt, X_train, Y_train, cv=kfold, scoring='f1').mean()
rf_score = cross_val_score(rf, X_train, Y_train, cv=kfold, scoring='f1').mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-565-49c9cc552320> in <module>
#      18 kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
#      19 # melakukan cross validation pada masing-masing metode
# ---> 20 lr_score = cross_val_score(log_regr, X_train, Y_train, cv=kfold, scoring='f1').mean()
#      21 svc_score = cross_val_score(svc, X_train, Y_train, cv=kfold, scoring='f1').mean()
#      22 dt_score = cross_val_score(dt, X_train, Y_train, cv=kfold, scoring='f1').mean()
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ...

# %%
for i in [lr_score, svc_score, dt_score, rf_score]:
    print(i)
# Out:
# nan
# nan
# nan
# nan
